# %% [markdown]
# ## Read the record.json file and access them

# %%
import json
fd=open("record.json",'r')
r=fd.read()
fd.close()

record=json.loads(r)

# %% [markdown]
# ### List of items available in the record

# %%
record
# Out:
# {'1001': {'name': 'Choco Cake',
#   'pr': 100,
#   'qn': 44,
#   'category': 'food',
#   'Discount': 0},
#  '1002': {'name': 'Milk Cake',
#   'pr': 800,
#   'qn': 100,
#   'category': 'food',
#   'Discount': 5},
#  '1003': {'name': 'Drink',
#   'pr': 85,
#   'qn': 100,
#   'category': 'beverages',
#   'Discount': 2},
#  '1004': {'name': 'Candy',
#   'pr': 5,
#   'qn': 1000,
#   'category': 'food',
#   'Discount': 0},
#  '1005': {'name': 'Pen',
#   'pr': 20,
#   'qn': 100,
#   'category': 'stationery',
#   'Discount': 0},
#  '1006': {'name': 'Mobile Phone',
#   'pr': 50000,
#   'qn': 10,
#   'category': 'electronic gadgets',
#   'Discount': 5},
#  '1007': {'name': 'Mic',
#   'pr': 1500,
#   'qn': 5,
#   'category': 'electronic gadgets',
#   'Discount': 0},
#  '1008': {'name': 'Mobile Case',
#   'pr': 499,
#   'qn': 15,
#   'category': 'electronic and gadgets',
#   'Discount': 0},
#  '1009': {'name': 'Keyboard',
#   'pr': 1999,
#   'qn': 10,
#   'category': 'electronic gadgets',
# ...

# %% [markdown]
# ### Code to insert inventory to the record.json

# %%
prod_id = str(input("Enter product id: "))
name = str(input("Enter name: "))
pr = int(input("Enter price: "))
qn = int(input("Enter quantity: "))
cat=str(input("enter the category of the item: "))
disc= int(input("enter the discount available on the item : "))

record[prod_id] = {'name': name, 'pr': pr, 'qn': qn, 'category' : cat, 'Discount' : disc}

js = json.dumps(record)

fd = open("record.json",'w')
fd.write(js)
fd.close()
# Out:
# Enter product id: 1030
# Enter name: cookies
# Enter price: 80
# Enter quantity: 142
# enter the category of the item: food
# enter the discount available on the item : 2
